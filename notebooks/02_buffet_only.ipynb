# %%
from datetime import date
import sys
from pathlib import Path

# Add src folder to sys.path so imports like 'from agent_lab...' work
sys.path.append(str(Path("../src").resolve()))

import pandas as pd
from agent_lab.data_connectors.finnhub_data import fetch_finnhub_fundamentals
from agent_lab.agents.buffett import BuffettAgent

# --- universe and fundamentals ---
universe = ["AAPL","MSFT","KO","BAC","JNJ","PG"]
fund = fetch_finnhub_fundamentals(universe)

# --- Buffett Agent ---
buff = BuffettAgent()
today = date.today()

decisions = []
for sym in universe:
    decisions.append(buff.decide(sym))

# --- Build readable table ---
rows = []
for d in decisions:
    row = fund.loc[d.symbol].to_dict()
    rows.append({
        "symbol": d.symbol,
        "Company": row.get("Company"),
        "pe_ratio": row.get("pe"),
        "roe": row.get("roe"),
        "debt_to_equity": row.get("debt_to_equity"),
        "free_cashflow": row.get("free_cashflow"),
        "sector": row.get("sector"),
        "Buffett Score": d.score,
        "Decision": d.action.name,
        "Confidence": d.confidence,
        "Justification": d.rationale
    })

buff_table = pd.DataFrame(rows).set_index("symbol")
buff_table.to_csv("buffett_decisions.csv")
print("✅ Buffett results saved to buffett_decisions.csv")
buff_table
# Out:
# ✅ Buffett results saved to buffett_decisions.csv
#                      Company  pe_ratio     roe  debt_to_equity  free_cashflow  \
# symbol
# AAPL               Apple Inc   33.9380  154.92               0              0
# MSFT          Microsoft Corp   37.2271   32.44               0              0
# KO              Coca-Cola Co   25.1409   45.90               0              0
# BAC     Bank of America Corp   12.7281    9.46               0              0
# JNJ        Johnson & Johnson   18.9890   30.39               0              0
# PG       Procter & Gamble Co   23.3988   30.78               0              0
#
#                    sector  Buffett Score Decision  Confidence  \
# symbol
# AAPL           Technology              3     HOLD        0.50
# MSFT           Technology              3     HOLD        0.50
# KO              Beverages              3     HOLD        0.50
# BAC               Banking              5      BUY        0.75
# JNJ       Pharmaceuticals              5      BUY        0.75
# PG      Consumer products              3     HOLD        0.50
#
#                                             Justification
# symbol
# AAPL    P/E high or NA | ROE strong | Debt OK | No FCF...
# MSFT    P/E high or NA | ROE strong | Debt OK | No FCF...
# KO      P/E high or NA | ROE strong | Debt OK | No FCF...
# BAC     P/E OK | ROE strong | Debt OK | No FCF | Secto...
# JNJ     P/E OK | ROE strong | Debt OK | No FCF | Secto...
# PG      P/E high or NA | ROE strong | Debt OK | No FCF...
