# %% [markdown]
# # Agent Lab — Quickstart
#
# This notebook demonstrates:
# 1. Loading free data with yfinance
# 2. Running Buffett & Momentum agents
# 3. Combining with OversightAgent

# %%
from datetime import date
import sys
from pathlib import Path
print(sys.executable)
# Add src folder to sys.path so imports like 'from agent_lab...' work
sys.path.append(str(Path("../src").resolve()))

import pandas as pd
from agent_lab.data_connectors.yf_market_data import fetch_prices, fetch_fundamentals, build_momentum_features
from agent_lab.agents.buffett import BuffettAgent
from agent_lab.agents.ackman import AckmanAgent
from agent_lab.agents.momentum import MomentumAgent
from agent_lab.agents.congress import CongressAgent
from agent_lab.ensemble.oversight import OversightAgent
from agent_lab.agents.base import Decision

# --- universe and data ---
universe = ["AAPL","MSFT","KO","BAC","JNJ","PG"]
prices = fetch_prices(universe, period="2y")
fund = fetch_fundamentals(universe)
mom = build_momentum_features(prices)

# --- agents ---
buff = BuffettAgent()
ack = AckmanAgent()
mom_agent = MomentumAgent()
cong = CongressAgent()
agents = [buff, ack, mom_agent, cong]

today = date.today()
all_decs = []

# --- gather decisions ---
for agent in agents:
    # select features per agent type
    if isinstance(agent, (BuffettAgent, AckmanAgent)):
        feat = fund
    elif isinstance(agent, MomentumAgent):
        feat = mom
    elif isinstance(agent, CongressAgent):
        feat = pd.DataFrame({
            "recent_congress_buy_usd": [0] * len(universe),
            "recent_congress_sell_usd": [0] * len(universe),
            "days_since_disclosure": [90] * len(universe)
        }, index=universe)
    else:
        raise ValueError(f"Unknown agent type: {type(agent)}")

    # --- call decide and get just the decisions (first element of tuple) ---
    decs, table = agent.decide(today, universe, feat)
    all_decs.extend(decs)

# --- build agent-level CSV ---
rows = []
for d in all_decs:
    row = fund.loc[d.symbol].to_dict()
    rows.append({
        "symbol": d.symbol,
        "Company": row.get("Company"),
        "agent": d.extras.get("agent_name", ""),
        "decision": d.action.name,
        "confidence": d.confidence,
        "score": d.score,
        "justification": d.rationale,
        "sector": d.extras.get("sector", None),
        "asof": d.extras.get("asof", None)
    })

agent_table = pd.DataFrame(rows)
agent_table.set_index(["symbol","agent"], inplace=True)
agent_table.to_csv("all_agents_votes.csv")
print("✅ All agent votes saved to all_agents_votes.csv")
print(agent_table)

# --- prepare dict for OversightAgent ---
all_decs_dict = {s: [d for d in all_decs if d.symbol == s] for s in universe}

# --- combine with OversightAgent ---
over = OversightAgent(agent_weights={
    "BuffettAgent": 1.0,
    "AckmanAgent": 0.9,
    "MomentumAgent": 0.8,
    "CongressAgent": 0.6
})
final_decisions = over.combine(all_decs_dict)

# --- final combined CSV ---
final_rows = []
for sym, d in final_decisions.items():
    final_rows.append({
        "symbol": sym,
        "final_decision": d.action.name,
        "final_confidence": d.confidence,
        "final_score": d.score,
        "rationale": d.rationale
    })

final_table = pd.DataFrame(final_rows)
final_table.set_index("symbol", inplace=True)
final_table.to_csv("final_oversight_decisions.csv")
print("✅ OversightAgent final decisions saved to final_oversight_decisions.csv")
print(final_table)
# Out:
# ✅ All agent votes saved to all_agents_votes.csv
#                                            Company decision  confidence  \
# symbol agent
# AAPL   BuffettAgent                     Apple Inc.     HOLD      0.5000
# MSFT   BuffettAgent          Microsoft Corporation     HOLD      0.5000
# KO     BuffettAgent          The Coca-Cola Company      BUY      0.7500
# BAC    BuffettAgent    Bank of America Corporation     HOLD      0.5000
# JNJ    BuffettAgent              Johnson & Johnson      BUY      0.9500
# PG     BuffettAgent   The Procter & Gamble Company      BUY      0.7500
# AAPL   AckmanAgent                      Apple Inc.      BUY      0.7500
# MSFT   AckmanAgent           Microsoft Corporation      BUY      0.7500
# KO     AckmanAgent           The Coca-Cola Company      BUY      0.7500
# BAC    AckmanAgent     Bank of America Corporation     HOLD      0.5000
# JNJ    AckmanAgent               Johnson & Johnson      BUY      0.9500
# PG     AckmanAgent    The Procter & Gamble Company      BUY      0.7500
# AAPL   MomentumAgent                    Apple Inc.     SELL      0.6500
# MSFT   MomentumAgent         Microsoft Corporation      BUY      0.6500
# KO     MomentumAgent         The Coca-Cola Company      BUY      0.6500
# BAC    MomentumAgent   Bank of America Corporation      BUY      0.6500
# JNJ    MomentumAgent             Johnson & Johnson      BUY      0.6500
# PG     MomentumAgent  The Procter & Gamble Company     SELL      0.6500
# AAPL   CongressAgent                    Apple Inc.     HOLD      0.0625
# MSFT   CongressAgent         Microsoft Corporation     HOLD      0.0625
# KO     CongressAgent         The Coca-Cola Company     HOLD      0.0625
# BAC    CongressAgent   Bank of America Corporation     HOLD      0.0625
# JNJ    CongressAgent             Johnson & Johnson     HOLD      0.0625
# PG     CongressAgent  The Procter & Gamble Company     HOLD      0.0625
#
#                       score  \
# symbol agent
# AAPL   BuffettAgent       4
# MSFT   BuffettAgent       4
# KO     BuffettAgent       5
# BAC    BuffettAgent       4
# JNJ    BuffettAgent       7
# PG     BuffettAgent       5
# AAPL   AckmanAgent        5
# MSFT   AckmanAgent        5
# KO     AckmanAgent        6
# BAC    AckmanAgent        3
# JNJ    AckmanAgent        7
# PG     AckmanAgent        6
# AAPL   MomentumAgent     -1
# MSFT   MomentumAgent      1
# KO     MomentumAgent      1
# BAC    MomentumAgent      1
# JNJ    MomentumAgent      1
# PG     MomentumAgent     -1
# AAPL   CongressAgent      0
# MSFT   CongressAgent      0
# KO     CongressAgent      0
# BAC    CongressAgent      0
# JNJ    CongressAgent      0
# PG     CongressAgent      0
#
#                                                           justification  \
# symbol agent
# AAPL   BuffettAgent   P/E high/NA | ROE>15% | Debt>Eq | +FreeCF | Se...
# MSFT   BuffettAgent   P/E high/NA | ROE>15% | Debt>Eq | +FreeCF | Se...
# KO     BuffettAgent   P/E high/NA | ROE>15% | Debt>Eq | +FreeCF | Se...
# BAC    BuffettAgent   P/E<20 | ROE low | Low debt | No FreeCF | Sect...
# JNJ    BuffettAgent   P/E<20 | ROE>15% | Debt>Eq | +FreeCF | Sector ...
# PG     BuffettAgent   P/E high/NA | ROE>15% | Debt>Eq | +FreeCF | Se...
# AAPL   AckmanAgent    P/E high/NA | ROE strong | Debt high | FreeCF ...
# MSFT   AckmanAgent    P/E high/NA | ROE strong | Debt high | FreeCF ...
# KO     AckmanAgent    P/E OK | ROE strong | Debt high | FreeCF posit...
# BAC    AckmanAgent    P/E OK | ROE weak | Debt manageable | No FreeC...
# JNJ    AckmanAgent    P/E OK | ROE strong | Debt high | FreeCF posit...
# PG     AckmanAgent    P/E OK | ROE strong | Debt high | FreeCF posit...
# AAPL   MomentumAgent                                       MA fast<slow
# MSFT   MomentumAgent                                       MA fast>slow
# KO     MomentumAgent                                       MA fast>slow
# BAC    MomentumAgent                                       MA fast>slow
# JNJ    MomentumAgent                                       MA fast>slow
# PG     MomentumAgent                                       MA fast<slow
# AAPL   CongressAgent                               No strong disclosure
# MSFT   CongressAgent                               No strong disclosure
# KO     CongressAgent                               No strong disclosure
# BAC    CongressAgent                               No strong disclosure
# JNJ    CongressAgent                               No strong disclosure
# PG     CongressAgent                               No strong disclosure
#
#                                   sector        asof
# symbol agent
# AAPL   BuffettAgent           Technology  2025-08-24
# MSFT   BuffettAgent           Technology  2025-08-24
# KO     BuffettAgent   Consumer Defensive  2025-08-24
# BAC    BuffettAgent   Financial Services  2025-08-24
# JNJ    BuffettAgent           Healthcare  2025-08-24
# PG     BuffettAgent   Consumer Defensive  2025-08-24
# AAPL   AckmanAgent            Technology  2025-08-24
# MSFT   AckmanAgent            Technology  2025-08-24
# KO     AckmanAgent    Consumer Defensive  2025-08-24
# BAC    AckmanAgent    Financial Services  2025-08-24
# JNJ    AckmanAgent            Healthcare  2025-08-24
# PG     AckmanAgent    Consumer Defensive  2025-08-24
# AAPL   MomentumAgent                None  2025-08-24
# MSFT   MomentumAgent                None  2025-08-24
# KO     MomentumAgent                None  2025-08-24
# BAC    MomentumAgent                None  2025-08-24
# JNJ    MomentumAgent                None  2025-08-24
# PG     MomentumAgent                None  2025-08-24
# AAPL   CongressAgent                None  2025-08-24
# MSFT   CongressAgent                None  2025-08-24
# KO     CongressAgent                None  2025-08-24
# BAC    CongressAgent                None  2025-08-24
# JNJ    CongressAgent                None  2025-08-24
# PG     CongressAgent                None  2025-08-24
# ✅ OversightAgent final decisions saved to final_oversight_decisions.csv
#        final_decision  final_confidence  final_score  \
# symbol
# AAPL             HOLD             0.155        0.155
# MSFT              BUY             1.000        1.195
# KO                BUY             1.000        1.945
# BAC               BUY             0.520        0.520
# JNJ               BUY             1.000        2.325
# PG                BUY             0.905        0.905
#
#                                                 rationale
# symbol
# AAPL    BuffettAgent:Action.HOLD(0.50); AckmanAgent:Ac...
# MSFT    BuffettAgent:Action.HOLD(0.50); AckmanAgent:Ac...
# KO      BuffettAgent:Action.BUY(0.75); AckmanAgent:Act...
# BAC     BuffettAgent:Action.HOLD(0.50); AckmanAgent:Ac...
# JNJ     BuffettAgent:Action.BUY(0.95); AckmanAgent:Act...
# PG      BuffettAgent:Action.BUY(0.75); AckmanAgent:Act...

# %%
if __name__ == "__main__":
    # fake fundamentals
    data = pd.DataFrame({
        "pe": [15, 30],
        "roe": [0.2, 0.05],
        "debt_to_equity": [0.5, 2.0],
        "free_cashflow": [100, -50],
        "sector": ["Consumer Defensive", "Tech"]
    }, index=["KO", "AAPL"])

    agent = BuffettAgent()
    decisions, table = agent.decide(date.today(), ["KO","AAPL"], data)

    print("Decisions:")
    for d in decisions:
        print(d)

    print("\nTable:")
    print(table)
# Out:
# Decisions:
# Decision(symbol='KO', action=<Action.BUY: 'BUY'>, confidence=0.95, score=8, rationale='P/E<20 | ROE>15% | Low debt | +FreeCF | Sector Consumer Defensive', extras={'sector': 'Consumer Defensive', 'asof': '2025-08-18', 'agent_name': 'BuffettAgent'})
# Decision(symbol='AAPL', action=<Action.SELL: 'SELL'>, confidence=0.2, score=0, rationale='P/E high/NA | ROE low | Debt>Eq | No FreeCF | Sector Tech (off)', extras={'sector': 'Tech', 'asof': '2025-08-18', 'agent_name': 'BuffettAgent'})
#
# Table:
#         score decision  confidence  \
# symbol
# KO          8      BUY        0.95
# AAPL        0     SELL        0.20
#
#                                             justification              sector
# symbol
# KO      P/E<20 | ROE>15% | Low debt | +FreeCF | Sector...  Consumer Defensive
# AAPL    P/E high/NA | ROE low | Debt>Eq | No FreeCF | ...                Tech
